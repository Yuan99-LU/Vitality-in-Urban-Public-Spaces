# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
import pyLDAvis
import pyLDAvis.sklearn
import pyLDAvis.gensim
import numpy as np
from datetime import datetime, date, time
import csv
import sys
import importlib
import pandas as pd

# %%
LANGUAGE = '[Japanese]'

# %%
def tf_vctorize(n_max_features, text):
    #n_features = 1000
    tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                max_features=n_max_features,
                                stop_words='english',
                                max_df = 0.95,
                                min_df = 2)
    tf = tf_vectorizer.fit_transform(text)
    tf_feature_names = tf_vectorizer.get_feature_names()
    return tf, tf_vectorizer, tf_feature_names
    

def LDA_analyze(tf_vector, n_topics):
    lda = LatentDirichletAllocation(n_topics=n_topics,doc_topic_prior =1/(n_topics*10), max_iter=50,
                                learning_method='online',
                                learning_offset=50.,
                                evaluate_every = 1,
                                random_state=0)
    lda.fit(tf_vector)
    print(lda)
    return lda

def tf_idf(n_max_features, text):
    tfidf_vectorizer = TfidfVectorizer(max_df=0.95,
                                       min_df=2,
                                       max_features=n_max_features,
                                       stop_words='english')
    tfidf = tfidf_vectorizer.fit_transform(text)
    tfidf_feature_names = tfidf_vectorizer.get_feature_names()
    return tfidf, tfidf_feature_names

# %%
data = pd.read_csv('things_to_basic_senti_analysis.csv')

# %%
data_eng = data[data['review language']== LANGUAGE]

# %%
print(data_eng.head(50))
# Out:
#                                                poi_name    poi_id  \
# 1399  Kulturen_in_Lund_Museum_of_Cultural_History_an...   d267409
# 1400  Kulturen_in_Lund_Museum_of_Cultural_History_an...   d267409
# 1401  Kulturen_in_Lund_Museum_of_Cultural_History_an...   d267409
# 1402  Kulturen_in_Lund_Museum_of_Cultural_History_an...   d267409
# 1403  Kulturen_in_Lund_Museum_of_Cultural_History_an...   d267409
# 1404  Kulturen_in_Lund_Museum_of_Cultural_History_an...   d267409
# 1405  Kulturen_in_Lund_Museum_of_Cultural_History_an...   d267409
# 1922                                     Lund_Cathedral   d319367
# 1923                                     Lund_Cathedral   d319367
# 1924                                     Lund_Cathedral   d319367
# 1925                                     Lund_Cathedral   d319367
# 1926                                     Lund_Cathedral   d319367
# 1927                                     Lund_Cathedral   d319367
# 1928                                     Lund_Cathedral   d319367
# 1929                                     Lund_Cathedral   d319367
# 1930                                     Lund_Cathedral   d319367
# 1931                                     Lund_Cathedral   d319367
# 1932                                     Lund_Cathedral   d319367
# 1933                                     Lund_Cathedral   d319367
# 1934                                     Lund_Cathedral   d319367
# 1935                                     Lund_Cathedral   d319367
# 1936                                     Lund_Cathedral   d319367
# 1937                                     Lund_Cathedral   d319367
# 2251             Botanical_Gardens_Botaniska_Tradgarden   d319374
# 2252             Botanical_Gardens_Botaniska_Tradgarden   d319374
# 2253             Botanical_Gardens_Botaniska_Tradgarden   d319374
# 2254             Botanical_Gardens_Botaniska_Tradgarden   d319374
# 2255             Botanical_Gardens_Botaniska_Tradgarden   d319374
# 2348                                          Jakriborg  d1889146
# 2349                                          Jakriborg  d1889146
# 2350                                          Jakriborg  d1889146
# 2446                                        Stadsparken  d8126652
# 2485  Lund_University_Historical_Museum_Historiska_M...   d319381
# 2486  Lund_University_Historical_Museum_Historiska_M...   d319381
# 2537                             All_Saints_Church_Lund   d735398
# 2538                             All_Saints_Church_Lund   d735398
# 2559                      Lund_University_Main_Building  d9750031
# 2560                      Lund_University_Main_Building  d9750031
# 2561                      Lund_University_Main_Building  d9750031
# 2562                      Lund_University_Main_Building  d9750031
#
#       total review count  average rating score  price              address  \
# 1399               325.0                   4.5    NaN       Tegnersplatsen
# 1400               325.0                   4.5    NaN       Tegnersplatsen
# 1401               325.0                   4.5    NaN       Tegnersplatsen
# 1402               325.0                   4.5    NaN       Tegnersplatsen
# 1403               325.0                   4.5    NaN       Tegnersplatsen
# 1404               325.0                   4.5    NaN       Tegnersplatsen
# 1405               325.0                   4.5    NaN       Tegnersplatsen
# 1922              1009.0                   4.5    NaN         Kyrkogatan 6
# 1923              1009.0                   4.5    NaN         Kyrkogatan 6
# 1924              1009.0                   4.5    NaN         Kyrkogatan 6
# 1925              1009.0                   4.5    NaN         Kyrkogatan 6
# 1926              1009.0                   4.5    NaN         Kyrkogatan 6
# 1927              1009.0                   4.5    NaN         Kyrkogatan 6
# 1928              1009.0                   4.5    NaN         Kyrkogatan 6
# 1929              1009.0                   4.5    NaN         Kyrkogatan 6
# 1930              1009.0                   4.5    NaN         Kyrkogatan 6
# 1931              1009.0                   4.5    NaN         Kyrkogatan 6
# 1932              1009.0                   4.5    NaN         Kyrkogatan 6
# 1933              1009.0                   4.5    NaN         Kyrkogatan 6
# 1934              1009.0                   4.5    NaN         Kyrkogatan 6
# 1935              1009.0                   4.5    NaN         Kyrkogatan 6
# 1936              1009.0                   4.5    NaN         Kyrkogatan 6
# 1937              1009.0                   4.5    NaN         Kyrkogatan 6
# 2251               503.0                   4.5    NaN  20 Oestra Vallgatan
# 2252               503.0                   4.5    NaN  20 Oestra Vallgatan
# 2253               503.0                   4.5    NaN  20 Oestra Vallgatan
# 2254               503.0                   4.5    NaN  20 Oestra Vallgatan
# 2255               503.0                   4.5    NaN  20 Oestra Vallgatan
# 2348                88.0                   3.5    NaN               Hjarup
# 2349                88.0                   3.5    NaN               Hjarup
# 2350                88.0                   3.5    NaN               Hjarup
# 2446               141.0                   4.5    NaN           Svanegatan
# 2485                66.0                   4.0    NaN         1 Kraftstorg
# 2486                66.0                   4.0    NaN         1 Kraftstorg
# 2537                66.0                   4.5    NaN         34 Bredgatan
# 2538                66.0                   4.5    NaN         34 Bredgatan
# 2559                55.0                   4.5    NaN       2 Paradisgatan
# 2560                55.0                   4.5    NaN       2 Paradisgatan
# 2561                55.0                   4.5    NaN       2 Paradisgatan
# 2562                55.0                   4.5    NaN       2 Paradisgatan
#
#      postcode       category review language  review count by language  \
# 1399   223 50  LocalBusiness      [Japanese]                         7
# 1400   223 50  LocalBusiness      [Japanese]                         7
# 1401   223 50  LocalBusiness      [Japanese]                         7
# 1402   223 50  LocalBusiness      [Japanese]                         7
# 1403   223 50  LocalBusiness      [Japanese]                         7
# 1404   223 50  LocalBusiness      [Japanese]                         7
# 1405   223 50  LocalBusiness      [Japanese]                         7
# 1922      NaN  LocalBusiness      [Japanese]                        16
# 1923      NaN  LocalBusiness      [Japanese]                        16
# 1924      NaN  LocalBusiness      [Japanese]                        16
# 1925      NaN  LocalBusiness      [Japanese]                        16
# 1926      NaN  LocalBusiness      [Japanese]                        16
# 1927      NaN  LocalBusiness      [Japanese]                        16
# 1928      NaN  LocalBusiness      [Japanese]                        16
# 1929      NaN  LocalBusiness      [Japanese]                        16
# 1930      NaN  LocalBusiness      [Japanese]                        16
# 1931      NaN  LocalBusiness      [Japanese]                        16
# 1932      NaN  LocalBusiness      [Japanese]                        16
# 1933      NaN  LocalBusiness      [Japanese]                        16
# 1934      NaN  LocalBusiness      [Japanese]                        16
# 1935      NaN  LocalBusiness      [Japanese]                        16
# 1936      NaN  LocalBusiness      [Japanese]                        16
# 1937      NaN  LocalBusiness      [Japanese]                        16
# 2251   223 61  LocalBusiness      [Japanese]                         5
# 2252   223 61  LocalBusiness      [Japanese]                         5
# 2253   223 61  LocalBusiness      [Japanese]                         5
# 2254   223 61  LocalBusiness      [Japanese]                         5
# 2255   223 61  LocalBusiness      [Japanese]                         5
# 2348    24565  LocalBusiness      [Japanese]                         3
# 2349    24565  LocalBusiness      [Japanese]                         3
# 2350    24565  LocalBusiness      [Japanese]                         3
# 2446   222 29  LocalBusiness      [Japanese]                         1
# 2485   223 50  LocalBusiness      [Japanese]                         2
# 2486   223 50  LocalBusiness      [Japanese]                         2
# 2537   222 21  LocalBusiness      [Japanese]                         2
# 2538   222 21  LocalBusiness      [Japanese]                         2
# 2559   223 50  LocalBusiness      [Japanese]                         4
# 2560   223 50  LocalBusiness      [Japanese]                         4
# 2561   223 50  LocalBusiness      [Japanese]                         4
# 2562   223 50  LocalBusiness      [Japanese]                         4
#
#               ...            author_votes  rating score          rating date  \
# 1399          ...                    13.0             3    October 25, 2018
# 1400          ...                     7.0             5   September 8, 2018
# 1401          ...                    13.0             3       July 10, 2018
# 1402          ...                    45.0             4      April 18, 2017
# 1403          ...                   142.0             4    October 20, 2016
# 1404          ...                    49.0             4        June 6, 2015
# 1405          ...                    12.0             4     October 2, 2014
# 1922          ...                     6.0             4   September 8, 2018
# 1923          ...                    60.0             4       July 31, 2018
# 1924          ...                    11.0             5       July 10, 2018
# 1925          ...                    43.0             4        May 29, 2018
# 1926          ...                    42.0             4      March 28, 2017
# 1927          ...                     3.0             5    November 6, 2016
# 1928          ...                   137.0             4    October 20, 2016
# 1929          ...                     8.0             5   September 8, 2016
# 1930          ...                     6.0             5      August 6, 2016
# 1931          ...                   172.0             4     January 2, 2016
# 1932          ...                     6.0             5  September 13, 2015
# 1933          ...                   104.0             5       July 22, 2015
# 1934          ...                    52.0             4       June 25, 2015
# 1935          ...                     NaN             4     January 3, 2015
# 1936          ...                    12.0             3     October 2, 2014
# 1937          ...                   101.0             4  September 11, 2014
# 2251          ...                     7.0             4   September 8, 2018
# 2252          ...                    13.0             4       July 12, 2018
# 2253          ...                    43.0             3      March 27, 2017
# 2254          ...                     4.0             5    November 6, 2016
# 2255          ...                    12.0             4     October 2, 2014
# 2348          ...                    13.0             5    October 25, 2018
# 2349          ...                    13.0             5        July 9, 2018
# 2350          ...                   143.0             4    October 20, 2016
# 2446          ...                     1.0             4        May 17, 2018
# 2485          ...                   143.0             3    October 20, 2016
# 2486          ...                   686.0             3     August 21, 2016
# 2537          ...                   143.0             4    October 20, 2016
# 2538          ...                   105.0             5       July 22, 2015
# 2559          ...                    43.0             4          1 week ago
# 2560          ...                   137.0             4    October 20, 2016
# 2561          ...                   389.0             4  September 26, 2016
# 2562          ...                    22.0             4       July 20, 2016
#
#                        rating title             rating place  \
# 1399                     昔のスウェーデン文化            Malmo, Sweden
# 1400                      スウェーデンの歴史                      NaN
# 1401                   スウェーデンの昔の暮らし            Malmo, Sweden
# 1402                       明治村的な博物館  Tokyo Prefecture, Japan
# 1403                      スウェーデンの歴史  Tokyo Prefecture, Japan
# 1404                   まちの中の民族野外博物館                    Osaka
# 1405         スウェーデンの昔の生活を垣間見ることができる  Tokyo Prefecture, Japan
# 1922                         歴史ある建物                      NaN
# 1923                    すごく歴史のある大聖堂                      NaN
# 1924                        一見の価値あり                    malmo
# 1925                            中心地  Tokyo Prefecture, Japan
# 1926                          駅から近い                      NaN
# 1927                         ただ声も出ず                      NaN
# 1928                             荘厳  Tokyo Prefecture, Japan
# 1929                     ルンドを代表する教会                    Japan
# 1930                    ガイドツアーも価値あり            Malmo, Sweden
# 1931                             偶然             Kyoto, Japan
# 1932                     ルンドを訪れたら必見                    Dubai
# 1933                         重厚な聖堂。           Yachiyo, Japan
# 1934                 存在感のある大きな荘厳な建物          Yokohama, Japan
# 1935            クリスマスの厳かな雰囲気を味わいました                       東京
# 1936                        歴史のある教会  Tokyo Prefecture, Japan
# 1937      からくり時計がちょうど鳴り始める12時に入りました  Nakano-ku, Tokyo, Japan
# 2251                    気持ちが良い場所です。                      NaN
# 2252                       世界各国の木や花            Malmo, Sweden
# 2253                         小さな植物園                      NaN
# 2254                       すばらしい植物園                      NaN
# 2255                      珍しい無料の植物園  Tokyo Prefecture, Japan
# 2348                 こじんまりした可愛らしい地区            Malmo, Sweden
# 2349                カラフルでオシャレな小さな地区            Malmo, Sweden
# 2350                         綺麗な街並み  Tokyo Prefecture, Japan
# 2446                         公園で日光浴                      NaN
# 2485                       大学の歴史を知る  Tokyo Prefecture, Japan
# 2486                    緑に囲まれたキャンパス                      NaN
# 2537                       こちらも良いです  Tokyo Prefecture, Japan
# 2538                      大聖堂よりこっち！           Yachiyo, Japan
# 2559                           落ち着く  Tokyo Prefecture, Japan
# 2560                       緑豊かな大学です  Tokyo Prefecture, Japan
# 2561  建物内には入れませんが、外観を見るだけでも価値があります。          Maebashi, Japan
# 2562                   屋根に４頭のスフィンクス             Tokyo, Japan
#
#                                                    text  \
# 1399  昔のスウェーデン文化や生活、遺跡に興味がある方には楽しめると思います。入り口にはスウェーデン...
# 1400  スウェーデンの歴史を様々な展示物で見ることができます。英語の説明があるので内容も理解できます...
# 1401  スウェーデンの昔の暮らしが垣間見れます。興味がある方には良いでしょう。ないと逆に退屈しそうで...
# 1402  古い家屋などが展示されている野外博物館。屋内にも展示物が多数あります。特に貧しかった頃のスウ...
# 1403  ここへ来れば、スウェーデンの歴史と昔の暮らしを知ることができると思います。建物だけでなく、日...
# 1404  ルンド大聖堂やルンド大学、王の家などが点在する公園を抜けたところにある博物館クルトゥーレン。...
# 1405  南スウェーデンの昔の生活を見ることができる。当時の物を見るだけではなく、実際に家に入って当時...
# 1922  石づくりの重厚な教会です。無料で中を見物できます。決まった時間に英語でのガイドツアーもありま...
# 1923  ルンド大学の近くにある大きな大聖堂で12世紀に建てられたそうです。石造りの外壁は所々黒くなっ...
# 1924  Lundといったらここです。駅から徒歩五分ほど。外観にまず圧倒されます。内装もきれいで広いで...
# 1925  ルンドの中心にある大聖堂。補修していないせいか外観は黒ずんでいるものの、荘厳な雰囲気がある教...
# 1926  ルンド中央駅からも少し歩くだけで行ける。聖堂の周りには歴史的背景などの説明もあり、英語での記...
# 1927  かなり歴史のある、荘厳な雰囲気のある教会でした。\n精巧な造り、彫刻のすばらしさは感動します...
# 1928  ルンドでの仕事の際、時間があったのでふらっと立ち寄りました。観光目的でなかったので期待せずに...
# 1929  駅から少し歩くと見えてきます。まず何より、歴史を感じさせる年季の入った石造りの外観と厳かな雰...
# 1930  ガイドツアー（英語）に参加しました。大聖堂の歴史や構造、伝説など、内部を回りながら、とても丁...
# 1931  コペンハーゲンからストックホルムの電車に乗り遅れたので、立ち寄ることになった街ルンド。正直ル...
# 1932  ルンドという小さな街にとって、街の中心にあるシンボリックな建築物。15世紀頃から動いていると...
# 1933  ルンド駅から歩いて7分ほどのところにある大聖堂。\n重々しい石造りの外観が、歴史の堆積を感じ...
# 1934  小さな町のルンドで、存在感のある大きな荘厳な建物です。大聖堂内では厳かな雰囲気を味わえます。...
# 1935  ルンド駅から徒歩７分程度、宿泊したホテルから５分以内でしたので朝、晩何度も訪ねました。私が宿...
# 1936  非常に歴史のある教会。中になる仕掛け時計の作りこみは圧巻。地下にはこの教会ができた時に石にな...
# 1937  外観は黒っぽく威圧的な感じですが，中に入るとスッキリとしたシンプルな作りで，広々としていまし...
# 2251  ９月に訪問しました。街の中心に近いので徒歩で駅からいけます。園内には様々な植物があり楽しめま...
# 2252  春に桜の木を探しに行きました。色々な各国の木や植物があり、木の幹にはネームタグがあるので勉強...
# 2253  ルンド大学が所有しているボタニカルガーデンであり、小さいながらも温室や池などもある。敷地内に...
# 2254  大学の研究施設です。\n残念ながら休館日で中を見ることができませんでした。\n次に訪れた時に...
# 2255  珍しい無料の植物園。無料とはいえバカにはできず、温室内には日本のものなど、本来ならばスウェー...
# 2348  たしか90年代頃に、都市計画で作られた小さな住宅地。街や建物は古いドイツの家を模倣したような...
# 2349  昔のドイツの家をモデルに都市計画でつくられた新しい小さな街。石畳みにカラフルな家々が立ち並び...
# 2350  ルンドからの移動の際に立ち寄りました。なかなか見ない建物、風景で海外に来たことを実感できる場...
# 2446  日本では見る機会のない植物を見ることができます。天気の良い日にピクニックに行くのをお勧めしま...
# 2485  大学訪問の際、少しだけ立ち寄りました。時間がなかったので雰囲気を感じる程度でしたが、大学だけ...
# 2486  既に閉館時間になってしまい、内部は見学できませんでしたが、公園みたいなキャンパスを散歩してい...
# 2537  ルンド大聖堂から近かったので立ち寄りました。大聖堂よりもこの教会のほうが豪華な感じがしました...
# 2538  ルンドの観光スポットでは大聖堂が有名ですが、さほど遠くないところにあるこの教会も素晴らしいで...
# 2559  スウエーデン最高学府の１つであるLund大学。広大なキャンパスにたつ建物はとても趣きがあり、...
# 2560  大変歴史を感じる建物で素晴らしいです。建物の周りは豊かな緑に囲われ、大学に通う学生が羨ましく...
# 2561  １６６６年にルンド大学ができたそうですが、歴史を感じさせる建物が多かったです。特に真っ白な大...
# 2562  ある国際会議のレセプションで利用した。夏至に近い頃で、よく手入れされ花が咲き誇る公園のような...
#
#                                               eng_title  \
# 1399                            The old Swedish culture
# 1400                               Sweden&#39;s history
# 1401                              Sweden&#39;s old life
# 1402                                  Meiji-mura museum
# 1403                               Sweden&#39;s history
# 1404                     Ethnic open-air museum in town
# 1405   You can catch a glimpse of Sweden&#39;s old life
# 1922                                  Historic building
# 1923                          A very historic cathedral
# 1924                                      Worth a visit
# 1925                                      Central place
# 1926                               Close to the station
# 1927                                      Just no voice
# 1928                                          Solemnity
# 1929                       The church representing Lund
# 1930                          Guided tour is also worth
# 1931                                         accidental
# 1932                         Must see if you visit Lund
# 1933                                 A heavy cathedral.
# 1934              Great majestic building with presence
# 1935            I felt Christmas&#39;s harsh atmosphere
# 1936                                    Historic church
# 1937  I entered at 12 o&#39;clock when the Karakuri ...
# 2251                            It is a pleasant place.
# 2252                 Trees and flowers around the world
# 2253                               Small botanic garden
# 2254                       A wonderful botanical garden
# 2255                      Unusual free botanical garden
# 2348                          Small and lovely district
# 2349                Colorful and stylish small district
# 2350                                    Clear cityscape
# 2446                             Sunbathing in the park
# 2485                 Know the history of the university
# 2486                         Campus surrounded by green
# 2537                                  Here is also good
# 2538                           Here from the cathedral!
# 2559                                          Calm down
# 2560                           It is a lush university.
# 2561  You can not enter the building, but just watch...
# 2562                          Four Sphinxes on the roof
#
#                                                eng_text basic_sentiment_text  \
# 1399  I think that you can enjoy it for people who a...             0.241667
# 1400  You can see the history of Sweden with various...             0.166667
# 1401  Sweden&#39;s old life is a glimpse. It is good...             0.143750
# 1402  An outdoor museum where old houses etc are dis...             0.140000
# 1403  If you come here, I think that you can know th...             0.183333
# 1404  The museum Kulturen which is through the park ...             0.250000
# 1405  You can see the old life of South Sweden. In a...             0.150000
# 1922  It is a heavy church of stone building. You ca...             0.160000
# 1923  It was said that it was built in the 12th cent...             0.129524
# 1924  Speaking of Lund, it is here. About 5 minutes ...             0.372222
# 1925  The cathedral in the center of Lund. It is a c...             0.200000
# 1926  You can also go from Lund Central Station by a...             0.083333
# 1927  It was a church with quite a history, majestic...             0.737500
# 1928  When I worked at Lund, I stopped by because I ...             0.500000
# 1929  You will see it when you walk a bit from the s...             0.183333
# 1930  I participated in a guided tour (English). You...             0.123333
# 1931  Because I missed the train in Stockholm from C...             0.550000
# 1932  For a small town called Lund, a symbolic build...             0.112500
# 1933  It is a cathedral which is about seven minutes...             0.750000
# 1934  Lund in a small town, it is a magnificent buil...             0.241667
# 1935  It took about 7 minutes on foot from Lund stat...             0.500000
# 1936  A very historic church. The making of an in-pr...             0.250000
# 1937  Although the appearance is dark and intimidati...             0.212500
# 2251  I visited in September. It is close to the cen...             0.320000
# 2252  I went to look for a cherry tree in the spring...             0.250000
# 2253  It is a botanical garden owned by Lund Univers...             0.083333
# 2254  It is a research facility at the university. U...            -0.200000
# 2255  A rare free botanical garden. Although it is f...             0.133333
# 2348  Certainly in the early 1990s, it was a small r...             0.090476
# 2349  A new small city built by city planning based ...             0.140909
# 2350  I dropped in when I moved from Lund. It is a p...             0.411111
# 2446  In Japan you can see plants without opportunit...             0.311111
# 2485  When I visited the university, I dropped in on...             0.250000
# 2486  It was already closed and it was not possible ...             0.133333
# 2537  Because I was near from Lund Cathedral, I drop...             0.225000
# 2538  The Cathedral is famous for Lund&#39;s sights,...             0.316667
# 2559  Lund University, one of the highest universiti...             0.275000
# 2560  It is wonderful in a building that feels a lot...             0.443750
# 2561  It seems that Lund University was built in 166...             0.238095
# 2562  I used it at reception of one international co...             0.250000
#
#       basic_sentiment_title
# 1399               0.100000
# 1400               0.000000
# 1401               0.100000
# 1402               0.000000
# 1403               0.000000
# 1404               0.000000
# 1405               0.100000
# 1922               0.000000
# 1923               0.000000
# 1924               0.300000
# 1925               0.000000
# 1926               0.000000
# 1927               0.000000
# 1928               0.000000
# 1929               0.000000
# 1930               0.300000
# 1931               0.000000
# 1932               0.000000
# 1933              -0.200000
# 1934               0.800000
# 1935              -0.200000
# 1936               0.000000
# 1937               0.000000
# 2251               0.733333
# 2252               0.000000
# 2253              -0.250000
# 2254               1.000000
# 2255               0.300000
# 2348               0.125000
# 2349               0.183333
# 2350               0.100000
# 2446               0.000000
# 2485               0.000000
# 2486              -0.200000
# 2537               0.700000
# 2538               0.000000
# 2559               0.072222
# 2560               0.100000
# 2561               0.300000
# 2562               0.000000
#
# [40 rows x 21 columns]

# %%
print(data_eng['eng_text'].head(5))
# Out:
# 1399    I think that you can enjoy it for people who a...
# 1400    You can see the history of Sweden with various...
# 1401    Sweden&#39;s old life is a glimpse. It is good...
# 1402    An outdoor museum where old houses etc are dis...
# 1403    If you come here, I think that you can know th...
# Name: eng_text, dtype: object

# %%
#print(data['string'].head(1))

# %%
#data['string'] = data['string'].replace(np.nan, '', regex=True)

# %%
#data['string'] = data['string'].apply(str)

# %%
#print(data['string'])

# %%
text_all = (data_eng['eng_text']).tolist()

# %%
print(len(text_all))
# Out:
# 40

# %%
n_max_features=3000
n_topics = 10
n_top_words = 10

tf_vector, tf_vectorizer, tf_feature_names = tf_vctorize(n_max_features, text_all)
lda = LDA_analyze(tf_vector, n_topics)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:314: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=0.01,
#              evaluate_every=1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=50, mean_change_tol=0.001,
#              n_components=10, n_jobs=None, n_topics=10, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
#tfidf, tfidf_feature_names = tf_idf(n_max_features, text_all)
pyLDAvis.enable_notebook()
lda_prepared = pyLDAvis.sklearn.prepare(lda, tf_vector, tf_vectorizer)
pyLDAvis.show(lda_prepared)
# Out:
# Note: if you're in the IPython notebook, pyLDAvis.show() is not the best command
#       to use. Consider using pyLDAvis.display(), or pyLDAvis.enable_notebook().
#       See more information at http://pyLDAvis.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [21/May/2019 06:07:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/May/2019 06:07:22] "GET /LDAvis.css HTTP/1.1" 200 -
# 127.0.0.1 - - [21/May/2019 06:07:22] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/May/2019 06:07:22] "GET /LDAvis.js HTTP/1.1" 200 -

# %%
#print(lda_prepared)

# %%
N=10
for i in lda_prepared[3:]:
    #i.shape()
    print(i)
    N+=1
    #i.to_csv("output"+ str(N) +'.csv')
# Out:
# 30
# 0.01
# {'xlab': 'PC1', 'ylab': 'PC2'}
# [10, 6, 1, 8, 4, 9, 7, 2, 3, 5]

# %%
for topic_idx, topic in enumerate(lda.components_):
    print("Topic #%d:" % topic_idx)
    #print(topic)
    print(topic.argsort()[-10:-1])
    #print(topic.argsort()[:-n_top_words - 1:-1])
    #print(tf_feature_names)
# Out:
# Topic #0:
# [279 126 122 258  73 257 174 182  36]
# Topic #1:
# [ 30 277 105 210 193 149  52 201 197]
# Topic #2:
# [169  76  68  13  52  12 194  16  17]
# Topic #3:
# [ 39  80 283  57 205  59 197 111 179]
# Topic #4:
# [216 187 262 209  55  19  42 133 129]
# Topic #5:
# [279 126 122 258  73 257 174 182  36]
# Topic #6:
# [ 30 277 105 210 193 149  52 201 197]
# Topic #7:
# [ 57 133 137  42 274  35 197 179  24]
# Topic #8:
# [237 163  36 122 241 124 257  10 184]
# Topic #9:
# [135  19  24  66 297 163 279  55  58]

# %%
print(tf_feature_names)
# Out:
# ['00', '000', '10', '1000', '1080', '1085', '10th', '11', '1100', '1145', '11th', '12', '12th', '14th', '15', '15th', '17th', '19th', '1st', '20', '20th', '30', '3pm', '900', 'able', 'absolute', 'absolutely', 'access', 'accessible', 'according', 'acoustics', 'action', 'activities', 'actually', 'addition', 'adjacent', 'admire', 'admission', 'adults', 'afternoon', 'age', 'ages', 'ago', 'air', 'alike', 'alive', 'allow', 'allowed', 'altar', 'alter', 'amazing', 'amazingly', 'ambience', 'ancient', 'anytime', 'app', 'appreciate', 'april', 'arch', 'architectural', 'architecture', 'area', 'areas', 'array', 'arrived', 'art', 'artifacts', 'ask', 'asked', 'aspects', 'assembled', 'astrological', 'astronomic', 'astronomical', 'atmosphere', 'attached', 'attended', 'attraction', 'attractions', 'attractive', 'august', 'aula', 'austere', 'authentic', 'autumn', 'available', 'away', 'awe', 'awesome', 'baby', 'bar', 'basement', 'basic', 'basis', 'bathrooms', 'beatiful', 'beautiful', 'beautifull', 'beautifully', 'beauty', 'beds', 'believe', 'belonged', 'bench', 'benches', 'best', 'better', 'big', 'bigger', 'biggest', 'bird', 'birds', 'bit', 'blocks', 'bloom', 'blooming', 'blooms', 'boasts', 'book', 'boring', 'born', 'botan', 'botanic', 'botanical', 'break', 'bright', 'bring', 'brought', 'build', 'building', 'buildings', 'built', 'bushes', 'business', 'busy', 'buy', 'caf', 'cafe', 'cafes', 'calculate', 'calendar', 'called', 'calm', 'calming', 'came', 'campus', 'candle', 'candles', 'care', 'cared', 'carved', 'carvings', 'catacombs', 'catch', 'cathedral', 'cathedrals', 'catholic', 'caught', 'celebrate', 'celebrating', 'celebrations', 'cellar', 'center', 'central', 'centre', 'centuries', 'century', 'ceramics', 'certainly', 'chance', 'characters', 'charge', 'charming', 'check', 'child', 'children', 'chimes', 'choir', 'chose', 'christian', 'christianity', 'christmas', 'church', 'churches', 'city', 'classes', 'clean', 'clear', 'climate', 'climates', 'climbing', 'clock', 'close', 'closed', 'closes', 'cobbled', 'coffee', 'cold', 'collected', 'collection', 'color', 'colorful', 'colours', 'come', 'comes', 'compared', 'complete', 'concert', 'concerts', 'conservatory', 'constructed', 'contain', 'contains', 'cool', 'copenhagen', 'corner', 'cost', 'cosy', 'cottages', 'couldn', 'countryside', 'couple', 'couples', 'course', 'creepy', 'crowd', 'crowded', 'crypt', 'crypts', 'cultural', 'culture', 'cup', 'curious', 'cute', 'daily', 'danish', 'dark', 'date', 'dates', 'dating', 'day', 'days', 'decided', 'decorated', 'decoration', 'decorations', 'definitely', 'delightful', 'denmark', 'design', 'designed', 'details', 'detour', 'did', 'didn', 'different', 'disappointed', 'discover', 'display', 'displayed', 'displays', 'distance', 'diverse', 'does', 'doesn', 'doing', 'dominates', 'dominating', 'domkyrkan', 'don', 'door', 'doors', 'downstairs', 'downtown', 'drink', 'drinking', 'drinks', 'ducks', 'dwellings', 'early', 'earth', 'easily', 'east', 'easy', 'eat', 'eating', 'elements', 'end', 'ended', 'english', 'enjoy', 'enjoyable', 'enjoyed', 'enjoying', 'enormous', 'enter', 'entering', 'entire', 'entrance', 'entry', 'environment', 'equipment', 'era', 'especially', 'europe', 'european', 'evening', 'event', 'events', 'everybody', 'example', 'excellent', 'exception', 'exercise', 'exhibit', 'exhibition', 'exhibitions', 'exhibits', 'exotic', 'expect', 'expected', 'expensive', 'experience', 'experiencing', 'explanation', 'explanations', 'explore', 'exploring', 'extensive', 'exterior', 'externally', 'extremely', 'eyes', 'fabulous', 'facing', 'fact', 'facts', 'fairly', 'fall', 'families', 'family', 'famous', 'fantastic', 'far', 'fascinating', 'favorite', 'features', 'fee', 'feed', 'feel', 'feeling', 'feels', 'felt', 'festival', 'figure', 'figures', 'fika', 'filled', 'final', 'fine', 'finest', 'finn', 'floor', 'flower', 'flowers', 'focal', 'follow', 'food', 'forest', 'forget', 'form', 'formal', 'forum', 'founded', 'fountain', 'free', 'friendly', 'friends', 'fully', 'fun', 'furnished', ' ...

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-30 - 1:-1]]))
    print()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topic #0:
# lund buildings old museum sweden different swedish history houses visit time place interesting kulturen day trip really cathedral people outside went house exhibits times life culture small visited lived exhibitions
# Topic #1:
# kids place playground children liked peaceful really fun various bit enjoyed exhibits denmark great area going especially love caf outdoor old set fantastic perfect took season beauty summer amazing way
# Topic #2:
# exhibition art areas people april children architectural dating early medieval religious noon different lund day crypt visited huge beautiful visit nice center church old fascinating cathedral interesting museum small century
# Topic #3:
# park nice good place close pond city walk enjoy cafe recommended people lund children little birds relax students coffee located miss day town outdoor play weather stadsparken look easily sunny
# Topic #4:
# clock impressive inside cathedral astronomical church read time outside religious giant town basement visit walking want small early recommend learn sun large quite little took loved built main attraction highly
# Topic #5:
# lund buildings old museum sweden different swedish history houses visit time place interesting kulturen day trip really cathedral people outside went house exhibits times life culture small visited lived exhibitions
# Topic #6:
# kids place playground children liked peaceful really fun various bit enjoyed exhibits denmark great area going especially love caf outdoor old set fantastic perfect took season beauty summer amazing way
# Topic #7:
# lund beautiful nice place building university cathedral just inside city year day recommend quiet famous spring walk town walking main great look center want garden students area like time huge
# Topic #8:
# museum open air sweden hours spent history buildings lund southern people houses enjoyed great building kulturen city entrance exhibitions culture really way showing walking fantastic interested nice swedish friendly visiting
# Topic #9:
# cathedral clock church visit lund worth crypt beautiful astronomical interesting inside history old impressive time giant miss amazing don free tour architecture visiting finn english building century town sweden visited
